# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
sys.path.append(r'c:/Users/hp/kifiya_acadamy_week6/kifiya_week6_assignment/scripts')
df = pd.read_csv('../data/data.csv')
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
from eda_toolkit import EDA

eda = EDA(df)

# %%
# Summary of the dataset
eda.summary()
# Out:
# Dataset Summary:
# Shape: (95662, 16)
#
# Data Types:
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# Duplicate values
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 95657    False
# 95658    False
# 95659    False
# 95660    False
# 95661    False
# Length: 95662, dtype: bool
#
# Missing Values:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# ...

# %%
numeric_data = df.select_dtypes(include=['number'])
print("Numeric Columns:\n", numeric_data.columns)
# Out:
# Numeric Columns:
#  Index(['CountryCode', 'Amount', 'Value', 'PricingStrategy', 'FraudResult'], dtype='object')

# %%
catagorical_data = df.select_dtypes(include=['object'])
print("catagorical_data:\n", catagorical_data.columns)
# Out:
# catagorical_data:
#  Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'ProviderId', 'ProductId', 'ProductCategory',
#        'ChannelId', 'TransactionStartTime'],
#       dtype='object')

# %%
# Perform dispersion analysis
eda.dispersion_analysis()
# Out:
# Range:
#  CountryCode               0.0
# Amount             10880000.0
# Value               9879998.0
# PricingStrategy           4.0
# FraudResult               1.0
# dtype: float64
#
# Variance:
#  CountryCode        0.000000e+00
# Amount             1.520457e+10
# Value              1.515905e+10
# PricingStrategy    5.371778e-01
# FraudResult        2.013471e-03
# dtype: float64
#
# Standard Deviation:
#  CountryCode             0.000000
# Amount             123306.797164
# Value              123122.087776
# PricingStrategy         0.732924
# FraudResult             0.044872
# dtype: float64
#
# Interquartile Range (IQR):
#  CountryCode           0.0
# Amount             2850.0
# Value              4725.0
# PricingStrategy       0.0
# FraudResult           0.0
# dtype: float64

# %%
skewness = numeric_data.skew()
print("Skewness:\n", skewness)
# Out:
# Skewness:
#  CountryCode         0.000000
# Amount             51.098490
# Value              51.291086
# PricingStrategy     1.659057
# FraudResult        22.196295
# dtype: float64

# %%
kurtosis = numeric_data.kurt()
print("Kurtosis:\n", kurtosis)
# Out:
# Kurtosis:
#  CountryCode           0.000000
# Amount             3363.127739
# Value              3378.069274
# PricingStrategy       2.087534
# FraudResult         490.685762
# dtype: float64

# %%
# Univariate analysis
eda.univariate_analysis(column='Amount', plot_type='boxplot')
eda.univariate_analysis(column='Value', plot_type='boxplot')
eda.univariate_analysis(column='FraudResult', plot_type='boxplot')

# %%
# Univariate analysis
eda.univariate_analysis(column='Amount', plot_type='histogram')
eda.univariate_analysis(column='Value', plot_type='histogram')
eda.univariate_analysis(column='FraudResult', plot_type='histogram')

# %%
# Multivariate analysis between Amount and Value
eda.multivariate_analysis('Amount', 'Value', plot_type='scatter')
eda.multivariate_analysis('Amount', 'Value', plot_type='correlation')

# %%
# Multivariate analysis between CountryCode and PricingStrategy
eda.multivariate_analysis('CountryCode', 'PricingStrategy', plot_type='scatter')
eda.multivariate_analysis('CountryCode', 'PricingStrategy', plot_type='correlation')

# %%
# Multivariate analysis between CountryCode and FraudResult
eda.multivariate_analysis('CountryCode', 'FraudResult', plot_type='scatter')
eda.multivariate_analysis('CountryCode', 'FraudResult', plot_type='correlation')

# %%
eda.multivariate_analysis('PricingStrategy', 'FraudResult', plot_type='scatter')
eda.multivariate_analysis('PricingStrategy', 'FraudResult', plot_type='correlation')

# %%
eda.multivariate_analysis('Amount', 'FraudResult', plot_type='scatter')
eda.multivariate_analysis('Amount', 'FraudResult', plot_type='correlation')

# %%
eda.multivariate_analysis('Value', 'FraudResult', plot_type='scatter')
eda.multivariate_analysis('Value', 'FraudResult', plot_type='correlation')

# %%
# Categorical analysis
eda.categorical_analysis('CurrencyCode')
eda.categorical_analysis('ProviderId')
eda.categorical_analysis('ProductId')
eda.categorical_analysis('ProductCategory')
eda.categorical_analysis('ChannelId')

# %%
# Detect outliers
outliers = eda.detect_outliers(column='Value', method='iqr')
print(outliers)
# Out:
#               TransactionId         BatchId       AccountId  \
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 52      TransactionId_38396  BatchId_110362  AccountId_2744
# 57      TransactionId_72438    BatchId_3221  AccountId_2744
# 110     TransactionId_50492   BatchId_29008   AccountId_946
# 114     TransactionId_74700   BatchId_72777   AccountId_946
# ...                     ...             ...             ...
# 95633   TransactionId_66516   BatchId_98969  AccountId_3014
# 95638   TransactionId_20690   BatchId_18591  AccountId_1232
# 95640  TransactionId_131580   BatchId_16209  AccountId_1219
# 95643  TransactionId_114220   BatchId_89378  AccountId_1318
# 95656   TransactionId_68402   BatchId_17092  AccountId_2659
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 3      SubscriptionId_2185   CustomerId_988          UGX          256
# 52     SubscriptionId_1665  CustomerId_3165          UGX          256
# ...

# %%
outliers = eda.detect_outliers(column='Amount', method='iqr')
print(outliers)
# Out:
#               TransactionId         BatchId       AccountId  \
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 6      TransactionId_118063  BatchId_118460  AccountId_2442
# 32       TransactionId_5351  BatchId_110904  AccountId_2540
# 39     TransactionId_104700   BatchId_55274  AccountId_2126
# 40      TransactionId_13858   BatchId_86043  AccountId_2126
# ...                     ...             ...             ...
# 95633   TransactionId_66516   BatchId_98969  AccountId_3014
# 95638   TransactionId_20690   BatchId_18591  AccountId_1232
# 95640  TransactionId_131580   BatchId_16209  AccountId_1219
# 95643  TransactionId_114220   BatchId_89378  AccountId_1318
# 95656   TransactionId_68402   BatchId_17092  AccountId_2659
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 3      SubscriptionId_2185   CustomerId_988          UGX          256
# 6      SubscriptionId_1980  CustomerId_2858          UGX          256
# ...

# %%
outliers = eda.detect_outliers(column='FraudResult', method='iqr')
print(outliers)
# Out:
#               TransactionId         BatchId       AccountId  \
# 131     TransactionId_60873   BatchId_93685  AccountId_3832
# 146     TransactionId_28016  BatchId_125553  AccountId_2366
# 155      TransactionId_1149   BatchId_10381  AccountId_3832
# 2376   TransactionId_136904   BatchId_52644  AccountId_3692
# 2452    TransactionId_88818   BatchId_54481  AccountId_3832
# ...                     ...             ...             ...
# 94805   TransactionId_69673  BatchId_111976  AccountId_4687
# 95108  TransactionId_128664  BatchId_128748  AccountId_1909
# 95262   TransactionId_33086   BatchId_40160  AccountId_1909
# 95264  TransactionId_100613   BatchId_40160  AccountId_1909
# 95268   TransactionId_44276   BatchId_19378  AccountId_1909
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 131    SubscriptionId_4161  CustomerId_4275          UGX          256
# 146    SubscriptionId_4834  CustomerId_7414          UGX          256
# ...
